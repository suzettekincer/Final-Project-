# %% [markdown]
# # Safety of Neighborhoods

# %% [markdown]
# ## Introduction

# %% [markdown]
# ## The Metric
# I am measuring the best neighborhood to have a family based on the safest neighborhood. To do this, I am measuring which neighborhood has the most Juvenile runaways.

# %%
import pandas as pd
data = pd.read_csv("Police-Blotter.csv", sep=',')
data.head(10)
# Out:
#        _id         PK       CCR  HIERARCHY         INCIDENTTIME  \
# 0  3160200  322852487  23160391         18  2023-10-09T02:51:00
# 1  3160201  322852762  23160392         10  2023-10-09T02:25:00
# 2  3160202  322852787  23160384          4  2023-10-09T01:40:00
# 3  3160203  322893569  23160534          6  2023-10-09T07:00:00
# 4  3160204  322917429  23160673         10  2023-10-09T16:30:00
# 5  3160205  324235775  23171535         27  2023-10-28T05:00:00
# 6  3160206  324798988  23176386         10  2023-11-06T10:30:00
# 7  3160207  324799806  23176355          0  2023-11-06T11:00:00
# 8  3160208  324806932  23176425          6  2023-11-05T22:30:00
# 9  3160209  324810215  23176417         99  2023-11-06T12:51:00
#
#                                 INCIDENTLOCATION CLEAREDFLAG  \
# 0   900 Block Cherokee Rdwy Pittsburgh, PA 15219           Y
# 1    2500 Block Chauncey Dr Pittsburgh, PA 15219           Y
# 2        Station St & Centre Ave Pittsburgh, PA            Y
# ...

# %%
data['OFFENSES'].value_counts()
# Out:
# 9999 9999 - (Misc. Incident):                                                                                                                                                                                       105
# 3921(a) Theft by Unlawful Taking or Disposition - Movable item                                                                                                                                                       94
# 3745 Accidents Involving Damage to Unattended Veh.or Prop.                                                                                                                                                           89
# 3304 Criminal Mischief.                                                                                                                                                                                              85
# ...

# %%
#query_mask = data['OFFENSES'] = '029 Missing Juvenile'
#kids = data[query_mask]
#kids.head()
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

s1 = pd.Series(data['INCIDENTHIERARCHYDESC'])
query_mask = s1.str.contains('RUNAWAYS', regex = False)

kids = data[query_mask]
kids.head(50)
# Out:
#           _id          PK       CCR  HIERARCHY         INCIDENTTIME  \
# 66    3160266   323914534  23168826         29  2023-10-24T08:30:00
# 74    3160274   324206030  23171073         29  2023-10-27T20:10:00
# 138   3160338   323976565  23169240         29  2023-10-24T21:07:00
# 192   3160392   323352060  23164068         29  2023-10-15T20:01:00
# 448   3160648   324614018  23172443         29  2023-10-30T05:39:00
# 460   3160660   324447638  23173254         29  2023-10-31T17:08:00
# 516   3160716 -3669000594  23173528         29  2023-11-01T04:33:00
# 548   3160748   324064888  23169925         29  2023-10-25T18:15:00
# 617   3160817   324117551  23170128         29  2023-10-26T10:15:00
# 793   3160993   324274086  23172309         29  2023-10-29T21:21:00
# 1087  3161287   324822008  23176580         29  2023-11-06T17:26:00
# 1102  3161302   324355525  23172687         29  2023-10-29T14:00:00
# 1109  3161309   322838329  23160150         29  2023-10-08T15:10:00
# ...

# %%
kids.plot.bar()
#crime = data.groupby("INCIDENTHIERARCHYDESC").sum()['number_of_steps']
#num_steps.sort_values(ascending=False)
# create dataframe with four columns and create a default plot
#df = pd.DataFrame(np.random.randn(1000, 4), index=random_series.index, columns=list('ABCD'))
#df.head()
# Out:
# /opt/tljh/user/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:677: UserWarning: The handle <BarContainer object of 26 artists> has a label of '_id' which cannot be automatically added to the legend.
#   ax.legend(handles, labels, loc="best", title=title)

# %%
fig = data.bar(df[kids], x = 'colour', y = 'count')
fig.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-54-50cf22d30d5d> in <module>
# ----> 1 fig = data.bar(df[kids], x = 'colour', y = 'count')
#       2 fig.show()
#
# /opt/tljh/user/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5581         ):
#    5582             return self[name]
# -> 5583         return object.__getattribute__(self, name)
#    5584
#    5585     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'bar'

# %%
df = data[["INCIDENTNEIGHBORHOOD", "INCIDENTHIERARCHYDESC"]]
data.head(10)
#df = df['INCIDENTNEIGHBORHOOD'].value_counts().sort_values(ascending=False)
# Out:
#        _id         PK       CCR  HIERARCHY         INCIDENTTIME  \
# 0  3160200  322852487  23160391         18  2023-10-09T02:51:00
# 1  3160201  322852762  23160392         10  2023-10-09T02:25:00
# 2  3160202  322852787  23160384          4  2023-10-09T01:40:00
# 3  3160203  322893569  23160534          6  2023-10-09T07:00:00
# 4  3160204  322917429  23160673         10  2023-10-09T16:30:00
# 5  3160205  324235775  23171535         27  2023-10-28T05:00:00
# 6  3160206  324798988  23176386         10  2023-11-06T10:30:00
# 7  3160207  324799806  23176355          0  2023-11-06T11:00:00
# 8  3160208  324806932  23176425          6  2023-11-05T22:30:00
# 9  3160209  324810215  23176417         99  2023-11-06T12:51:00
#
#                                 INCIDENTLOCATION CLEAREDFLAG  \
# 0   900 Block Cherokee Rdwy Pittsburgh, PA 15219           Y
# 1    2500 Block Chauncey Dr Pittsburgh, PA 15219           Y
# 2        Station St & Centre Ave Pittsburgh, PA            Y
# ...

# %%
pData = data.pivot(columns = "INCIDENTNEIGHBORHOOD", values = "INCIDENTHIERARCHYDESC")
pData.head(10)
# Out:
# INCIDENTNEIGHBORHOOD  NaN Allegheny Center Allegheny West Allentown Arlington  \
# 0                     NaN              NaN            NaN       NaN       NaN
# 1                     NaN              NaN            NaN       NaN       NaN
# 2                     NaN              NaN            NaN       NaN       NaN
# 3                     NaN              NaN            NaN       NaN       NaN
# 4                     NaN              NaN            NaN       NaN       NaN
# 5                     NaN              NaN            NaN       NaN       NaN
# 6                     NaN              NaN            NaN       NaN       NaN
# 7                     NaN              NaN            NaN       NaN       NaN
# 8                     NaN              NaN            NaN       NaN       NaN
# 9                     NaN              NaN            NaN       NaN       NaN
#
# INCIDENTNEIGHBORHOOD Arlington Heights Banksville  \
# 0                                  NaN        NaN
# ...

# %%
#df = df.sort_values(by="INCIDENTNEIGHBORHOOD")
df = df['INCIDENTNEIGHBORHOOD'].value_counts().sort_values(ascending=True)
df.head(100)
# Out:
# New Homestead                  1
# Windgap                        1
# Mount Oliver                   1
# Chartiers City                 2
# Ridgemont                      2
#                             ...
# Crawford-Roberts              50
# Shadyside                     57
# Carrick                       58
# South Side Flats             120
# Central Business District    186
# Name: INCIDENTNEIGHBORHOOD, Length: 90, dtype: int64

# %%
#df[10:].plot(kind = "bar", width = .6, figsize =(40, 20), ylim = (0, 10))
import matplotlib
matplotlib.style.use('fivethirtyeight')
#plt.style.use('seaborn')
df[0:10].plot.barh(x = "Neighborhood", y = "runaways",figsize=(30,15))
plt.title("Number of Runaway Children per Neighborhood")
plt.xlabel("Number of Children")
plt.ylabel("Neighborhood")
# Out:
# Text(0, 0.5, 'Neighborhood')

# %%
df = df['INCIDENTNEIGHBORHOOD'].value_counts().sort_values(ascending=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/tljh/user/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3620             try:
# -> 3621                 return self._engine.get_loc(casted_key)
#    3622             except KeyError as err:
#
# /opt/tljh/user/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /opt/tljh/user/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'INCIDENTNEIGHBORHOOD'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df.plot(kind = "bar")

# %%
df.plot(kind = "bar", width = .6, figsize =(40, 20), ylim = (0, 10))

# %%
q_mask = df['INCIDENTNEIGHBORHOOD'] < 10
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/tljh/user/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3620             try:
# -> 3621                 return self._engine.get_loc(casted_key)
#    3622             except KeyError as err:
#
# /opt/tljh/user/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /opt/tljh/user/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'INCIDENTNEIGHBORHOOD'
#
# The above exception was the direct cause of the following exception:
#
# ...
